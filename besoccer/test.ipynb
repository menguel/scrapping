# %%
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

BASE_URL = "https://fr.besoccer.com/"


def get_match_day():

    with requests.Session() as session:
        
        response = session.get(BASE_URL)
        soup = BeautifulSoup(response.text, 'html.parser')

        print(soup)


get_match_day()
# Out:
# <!DOCTYPE html>
#
# <html lang="fr">
# <head>
# <title>BeSoccer Livescore: les résultats de football de la journée en direct</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#51a331" name="theme-color"/>
# <meta content="5d0fed68154e52109a581e4a59e5dc85" name="jungleup"/>
# <meta content="1654057214881798" property="fb:pages">
# <link href="https://fonts.googleapis.com/css?family=Asap+Condensed:wght@400;600&amp;&amp;display=swap" rel="stylesheet"/>
# <link href="/manifest.webmanifest?v=2" rel="manifest"/>
# <link href="https://fr.besoccer.com/" rel="canonical"/>
# <link href="/media/css/style.css?20250402.5261" rel="stylesheet" type="text/css">
# <link href="/media/css/jquery-ui-1.12.4.min.css?20250402.5261" rel="stylesheet" type="text/css">
# <link href="/media/img/favicon/favicon-152.png" rel="apple-touch-icon-precomposed">
# <meta content="#FFFFFF" name="msapplication-TileColor"/>
# <meta content="/media/img/favicon/favicon2-144.png" name="msapplication-TileImage"/>
# <link href="/media/img/favicon/favicon-152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="/media/img/favicon/favicon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/media/img/favicon/favicon-120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="/media/img/favicon/favicon-114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/media/img/favicon/favicon-72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="/media/img/favicon/favicon-57.png" rel="apple-touch-icon-precomposed"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/favicon.ico" rel="icon" sizes="16x16 32x32"/>
# <script src="/media/js/jquery-3.4.1.min.js"></script>
# <script src="/media/js/basicUser.js"></script>
# <script src="/media/js/controlUserData.js?rand=20250402.52618"></script>
# <script src="/media/js/oddsFunctions.js?rand=20250402.5267"></script>
# <script src="/media/js/handleBets.js?rand=20250402.5265"></script>
# <link href="https://www.besoccer.com" hreflang="x-default" rel="alternate"/>
# <link href="https://es.besoccer.com" hreflang="es" rel="alternate"/>
# <link href="https://fr.besoccer.com" hreflang="fr" rel="alternate"/>
# <link href="https://it.besoccer.com" hreflang="it" rel="alternate"/>
# <link href="https://pt.besoccer.com" hreflang="pt" rel="alternate"/>
# <meta content="Profitez des résultats de football du jour sur BeSoccer Livescore⚽. Les scores en direct de tous les matchs de la Ligue1 dans toutes les journées et toutes les compétitions du monde." name="description"/>
# <meta content="app-id=550928207" name="apple-itunes-app"/>
# <meta content="app-id=com.resultadosfutbol.mobile" name="google-play-app"/>
# <meta content="BeSoccer Livescore: les résultats de football de la journée en direct" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://fr.besoccer.com/" property="og:url"/>
# <meta content="https://cdn.resfu.com/media/img/bs/besoccer_logo2.png" property="og:image"/>
# <meta content="Profitez des résultats de football du jour sur BeSoccer Livescore⚽. Les scores en direct de tous les matchs de la Ligue1 dans toutes les journées et toutes les compétitions du monde." property="og:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="b87076b755bdc2f6009d8a766e6aaa1f" name="p:domain_verify"/>
# <meta content="index, follow" name="robots"/>
# <meta content="100000511556948" property="fb:admins"/>
# <meta content="200183103347113" property="fb:app_id"/>
# <link href="https://chrome.google.com/webstore/detail/besoccer/fignadhkmohccfojmlnhmmhicbkafbng" rel="chrome-webstore-item"/>
# <script async="" defer="" src="https://accounts.google.com/gsi/client"></script>
# <script>
#             const name = "subscription=";
#             const adultName = "bs-bets-version-change=";
#             const cDecoded = decodeURIComponent(document.cookie);
#             const cArr = cDecoded.split('; ');
#             let subscriptionCookie = '';
#             let adultCookie = false;
#             cArr.forEach(val => {
#                 if (val.indexOf(name) === 0) {
#                     subscriptionCookie = val.substring(name.length);
#                 } else if(val.indexOf(adultName) === 0) {
#                     adultCookie = true;
#                 }
#             });
#             const countryCode = "cm";
#             const loadScript = (src) => new Promise((resolve, reject) => {
#                 let script = document.createElement('script')
#                 script.src = src
#                 script.onload = resolve
#                 script.onerror = reject
#                 document.head.appendChild(script)
#             })
#         </script>
# <script>
#             const adsList = null;
#             const adsCommon = {"desktop":{"side":{"id":["BS_DESKTOP_LEFT","BS_DESKTOP_RIGHT"],"attributes":["data-type","ads"],"class":["ad-box","right","left"]},"top":{"id":"BS_DESKTOP_TOP","attributes":["data-type","ads"],"class":["ad-box","top"],"width":"100%","max-height":"250px","align-items":"center"}},"mobile":{"top":{"id":"BS_MOBILE_TOP","attributes":["data-type","ads"],"class":["centerAds"]},"top_events":{"id":"BS_MOBILE_EVENTS","attributes":["data-type","ads"],"class":["centerAds"]},"middle":{"id":"BS_MOBILE_MIDDLE","attributes":["data-type","ads"],"class":["centerAds"]},"bottom":{"id":"BS_MOBILE_BOTTOM","attributes":["data-type","ads"],"class":["centerAds"]}},"section":"home"};
#             const ssmCode = 0;
#             const matchId = null;
#             const language = 'fr';
#             const sub_section = 'home';
#
#             const now = new Date();
#             const view = window.innerWidth >= 1024 ? 'desktop' : 'mobile';
#             var section = 'livescore';
#             const legalInfo = {
#                 banner: null,
#                 popup: null            };
#         </script>
# <script>
#                     if ( !subscriptionCookie ) {
#                         const today = new Date();
#                         const year = today.getFullYear();
#                         const month = String(today.getMonth() + 1).padStart(2, '0');
#                         const day = String(today.getDate()).padStart(2, '0');
#
#                         // 'YYYYMMDD'
#                         const cacheBuster = `${year}${month}${day}4`;
#                         // loadScript('https://ssm.codes/smart-tag/besoccercomv3.js?' + cacheBuster).then(() => {});
#                         loadScript('https://ssm.codes/smart-tag/besoccercomv3.js').then(() => {})
#                     }
#                 </script>
# <!-- InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script async="true" type="text/javascript">
#                 if ( !subscriptionCookie ) {
#                     (function() {
#                     var country = 'cm';
#                     if (country === 'es') {
#                         var host = 'es.besoccer.com';
#                     } else {
#                         var host = window.location.hostname;
#                         var arrayHost = host.split('.');
#                         if (arrayHost[0] === 'es') {
#                             arrayHost[0] = 'www';
#                             host = arrayHost.join('.');
#                         }
#                     }
#                     var element = document.createElement('script');
#                     var firstScript = document.getElementsByTagName('script')[0];
#                     var url = 'https://cmp.inmobi.com'
#                         .concat('/choice/', 'PM1PaqFTUH-yn', '/', host, '/choice.js?tag_version=V3');
#                     var uspTries = 0;
#                     var uspTriesLimit = 3;
#                     element.async = true;
#                     element.type = 'text/javascript';
#                     element.src = url;
#
#                     firstScript.parentNode.insertBefore(element, firstScript);
#
#                     function makeStub() {
#                         var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                         var queue = [];
#                         var win = window;
#                         var cmpFrame;
#
#                         function addFrame() {
#                         var doc = win.document;
#                         var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                         if (!otherCMP) {
#                             if (doc.body) {
#                             var iframe = doc.createElement('iframe');
#
#                             iframe.style.cssText = 'display:none';
#                             iframe.name = TCF_LOCATOR_NAME;
#                             doc.body.appendChild(iframe);
#                             } else {
#                             setTimeout(addFrame, 5);
#                             }
#                         }
#                         return !otherCMP;
#                         }
#
#                         function tcfAPIHandler() {
#                         var gdprApplies;
#                         var args = arguments;
#
#                         if (!args.length) {
#                             return queue;
#                         } else if (args[0] === 'setGdprApplies') {
#                             if (
#                             args.length > 3 &&
#                             args[2] === 2 &&
#                             typeof args[3] === 'boolean'
#                             ) {
#                             gdprApplies = args[3];
#                             if (typeof args[2] === 'function') {
#                                 args[2]('set', true);
#                             }
#                             }
#                         } else if (args[0] === 'ping') {
#                             var retr = {
#                             gdprApplies: gdprApplies,
#                             cmpLoaded: false,
#                             cmpStatus: 'stub'
#                             };
#
#                             if (typeof args[2] === 'function') {
#                             args[2](retr);
#                             }
#                         } else {
#                             if(args[0] === 'init' && typeof args[3] === 'object') {
#                             args[3] = Object.assign(args[3], { tag_version: 'V3' });
#                             }
#                             queue.push(args);
#                         }
#                         }
#
#                         function postMessageEventHandler(event) {
#                         var msgIsString = typeof event.data === 'string';
#                         var json = {};
#
#                         try {
#                             if (msgIsString) {
#                             json = JSON.parse(event.data);
#                             } else {
#                             json = event.data;
#                             }
#                         } catch (ignore) {}
#
#                         var payload = json.__tcfapiCall;
#
#                         if (payload) {
#                             window.__tcfapi(
#                             payload.command,
#                             payload.version,
#                             function(retValue, success) {
#                                 var returnMsg = {
#                                 __tcfapiReturn: {
#                                     returnValue: retValue,
#                                     success: success,
#                                     callId: payload.callId
#                                 }
#                                 };
#                                 if (msgIsString) {
#                                 returnMsg = JSON.stringify(returnMsg);
#                                 }
#                                 if (event && event.source && event.source.postMessage) {
#                                 event.source.postMessage(returnMsg, '*');
#                                 }
#                             },
#                             payload.parameter
#                             );
#                         }
#                         }
#
#                         while (win) {
#                         try {
#                             if (win.frames[TCF_LOCATOR_NAME]) {
#                             cmpFrame = win;
#                             break;
#                             }
#                         } catch (ignore) {}
#
#                         if (win === window.top) {
#                             break;
#                         }
#                         win = win.parent;
#                         }
#                         if (!cmpFrame) {
#                         addFrame();
#                         win.__tcfapi = tcfAPIHandler;
#                         win.addEventListener('message', postMessageEventHandler, false);
#                         }
#                     };
#
#                     makeStub();
#
#                     function makeGppStub() {
#                         const CMP_ID = 10;
#                         const SUPPORTED_APIS = [
#                         '2:tcfeuv2',
#                         '6:uspv1',
#                         '7:usnatv1',
#                         '8:usca',
#                         '9:usvav1',
#                         '10:uscov1',
#                         '11:usutv1',
#                         '12:usctv1'
#                         ];
#
#                         window.__gpp_addFrame = function (n) {
#                         if (!window.frames[n]) {
#                             if (document.body) {
#                             var i = document.createElement("iframe");
#                             i.style.cssText = "display:none";
#                             i.name = n;
#                             document.body.appendChild(i);
#                             } else {
#                             window.setTimeout(window.__gpp_addFrame, 10, n);
#                             }
#                         }
#                         };
#                         window.__gpp_stub = function () {
#                         var b = arguments;
#                         __gpp.queue = __gpp.queue || [];
#                         __gpp.events = __gpp.events || [];
#
#                         if (!b.length || (b.length == 1 && b[0] == "queue")) {
#                             return __gpp.queue;
#                         }
#
#                         if (b.length == 1 && b[0] == "events") {
#                             return __gpp.events;
#                         }
#
#                         var cmd = b[0];
#                         var clb = b.length > 1 ? b[1] : null;
#                         var par = b.length > 2 ? b[2] : null;
#                         if (cmd === "ping") {
#                             clb(
#                             {
#                                 gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#                                 cmpStatus: "stub", // possible values: stub, loading, loaded, error
#                                 cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#                                 signalStatus: "not ready", // possible values: not ready, ready
#                                 supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#                                 cmpId: CMP_ID, // IAB assigned CMP ID, may be 0 during stub/loading
#                                 sectionList: [],
#                                 applicableSections: [-1],
#                                 gppString: "",
#                                 parsedSections: {},
#                             },
#                             true
#                             );
#                         } else if (cmd === "addEventListener") {
#                             if (!("lastId" in __gpp)) {
#                             __gpp.lastId = 0;
#                             }
#                             __gpp.lastId++;
#                             var lnr = __gpp.lastId;
#                             __gpp.events.push({
#                             id: lnr,
#                             callback: clb,
#                             parameter: par,
#                             });
#                             clb(
#                             {
#                                 eventName: "listenerRegistered",
#                                 listenerId: lnr, // Registered ID of the listener
#                                 data: true, // positive signal
#                                 pingData: {
#                                 gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#                                 cmpStatus: "stub", // possible values: stub, loading, loaded, error
#                                 cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#                                 signalStatus: "not ready", // possible values: not ready, ready
#                                 supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#                                 cmpId: CMP_ID, // list of supported APIs
#                                 sectionList: [],
#                                 applicableSections: [-1],
#                                 gppString: "",
#                                 parsedSections: {},
#                                 },
#                             },
#                             true
#                             );
#                         } else if (cmd === "removeEventListener") {
#                             var success = false;
#                             for (var i = 0; i < __gpp.events.length; i++) {
#                             if (__gpp.events[i].id == par) {
#                                 __gpp.events.splice(i, 1);
#                                 success = true;
#                                 break;
#                             }
#                             }
#                             clb(
#                             {
#                                 eventName: "listenerRemoved",
#                                 listenerId: par, // Registered ID of the listener
#                                 data: success, // status info
#                                 pingData: {
#                                 gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#                                 cmpStatus: "stub", // possible values: stub, loading, loaded, error
#                                 cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#                                 signalStatus: "not ready", // possible values: not ready, ready
#                                 supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#                                 cmpId: CMP_ID, // CMP ID
#                                 sectionList: [],
#                                 applicableSections: [-1],
#                                 gppString: "",
#                                 parsedSections: {},
#                                 },
#                             },
#                             true
#                             );
#                         } else if (cmd === "hasSection") {
#                             clb(false, true);
#                         } else if (cmd === "getSection" || cmd === "getField") {
#                             clb(null, true);
#                         }
#                         //queue all other commands
#                         else {
#                             __gpp.queue.push([].slice.apply(b));
#                         }
#                         };
#                         window.__gpp_msghandler = function (event) {
#                         var msgIsString = typeof event.data === "string";
#                         try {
#                             var json = msgIsString ? JSON.parse(event.data) : event.data;
#                         } catch (e) {
#                             var json = null;
#                         }
#                         if (typeof json === "object" && json !== null && "__gppCall" in json) {
#                             var i = json.__gppCall;
#                             window.__gpp(
#                             i.command,
#                             function (retValue, success) {
#                                 var returnMsg = {
#                                 __gppReturn: {
#                                     returnValue: retValue,
#                                     success: success,
#                                     callId: i.callId,
#                                 },
#                                 };
#                                 event.source.postMessage(msgIsString ? JSON.stringify(returnMsg) : returnMsg, "*");
#                             },
#                             "parameter" in i ? i.parameter : null,
#                             "version" in i ? i.version : "1.1"
#                             );
#                         }
#                         };
#                         if (!("__gpp" in window) || typeof window.__gpp !== "function") {
#                         window.__gpp = window.__gpp_stub;
#                         window.addEventListener("message", window.__gpp_msghandler, false);
#                         window.__gpp_addFrame("__gppLocator");
#                         }
#                     };
#
#                     makeGppStub();
#
#                     var uspStubFunction = function() {
#                         var arg = arguments;
#                         if (typeof window.__uspapi !== uspStubFunction) {
#                         setTimeout(function() {
#                             if (typeof window.__uspapi !== 'undefined') {
#                             window.__uspapi.apply(window.__uspapi, arg);
#                             }
#                         }, 500);
#                         }
#                     };
#
#                     var checkIfUspIsReady = function() {
#                         uspTries++;
#                         if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                         console.warn('USP is not accessible');
#                         } else {
#                         clearInterval(uspInterval);
#                         }
#                     };
#
#                     if (typeof window.__uspapi === 'undefined') {
#                         window.__uspapi = uspStubFunction;
#                         var uspInterval = setInterval(checkIfUspIsReady, 6000);
#                     }
#                     })();
#                 }
#             </script>
# <!-- End InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <!-- Target -->
# <script type="text/javascript">
#                 window.ssmCustomTargetings = { name: "home"};
#             </script>
# <!-- EndTarget -->
# <!-- Google Tag Manager -->
# <script> (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-5LPMBRM'); </script>
# <!-- End Google Tag Manager -->
# <!-- test params for GA4 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-HZYHXD4GZ0"></script>
# <script>
#
#             window.dataLayer = window.dataLayer || [];
#             function gtag(){dataLayer.push(arguments);}
#             gtag('js', new Date());
#             gtag('config', 'G-HZYHXD4GZ0', {
#                 send_page_view: false
#             });
#
#             gtag('event', 'page_view', {
#                 'section': 'livescore',
#                 'section_id': '',
#                 'sub_section' : 'home'
#             });
#         </script>
# <!-- end test params for GA4 -->
# <!-- Statcounter Tag -->
# <script>
#             var sc_project=8608899;
#             var sc_invisible=1;
#             var sc_security="f9634e44";
#             var sc_https=1;
#         </script>
# <script async="" src="https://statcounter.com/counter/counter.js"></script>
# <!-- End Statcounter Tag -->
# <!-- Facebook Pixel Code -->
# <script>
#             !function(f,b,e,v,n,t,s)
#             {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                 n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                 if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                 n.queue=[];t=b.createElement(e);t.async=!0;
#                 t.src=v;s=b.getElementsByTagName(e)[0];
#                 s.parentNode.insertBefore(t,s)}(window, document,'script',
#                 'https://connect.facebook.net/en_US/fbevents.js');
#             fbq('init', '1918202381837292');
#             fbq('track', 'PageView');
#         </script>
# <!-- End Facebook Pixel Code -->
# <!-- Teads -->
# <script src="/_fs-ch-1T1wmsGaOgGaSxcX/assets/script.js"></script>
# <!-- TABOOLA -->
# <!-- END TABOOLA -->
# <!-- Test tags for GAM -->
# <script>
#             const specialTags = null;
#             let isAdult = localStorage.getItem('isAdult') ?? null;
#             isAdultParse = isAdult !== null ? JSON.parse(isAdult) : {name: 'no'};
#             window.ssmCustomTargetings = {
#                 'category' : 'livescore',
#                 'subcategory': 'home',
#                 'id' : '',
#                 'adult': isAdultParse.name === 'yes' ? 'true' : 'false',
#                 'lang' : 'fr'
#             }
#
#             if ( specialTags ) {
#                 for( let key in specialTags ) {
#                     window.ssmCustomTargetings[key] = specialTags[key]
#                 }
#             }
#
#         </script>
# <!-- end test -->
# </link></link></link></meta></head>
# <body class="centered" data-iso-code="cm" data-skin="0" id="livescore" style="height:auto;">
# <!-- FB Login -->
# <div id="fb-root"></div>
# <script async="" crossorigin="anonymous" defer="" nonce="AZmiljeh" src="https://connect.facebook.net/es_ES/sdk.js#xfbml=1&amp;version=v16.0"></script>
# <!-- End FB Login -->
# <!-- Facebook Pixel Code -->
# <noscript><img alt="noscript image" height="1" loading="lazy" src="https://www.facebook.com/tr?id=1918202381837292&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" sandbox="allow-scripts" src="https://www.googletagmanager.com/ns.html?id=GTM-5LPMBRM" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="ad-box ad-video-container">
# </div>
# <div class="" id="mod_bet_age_confirm">
# <div class="bet-age-confirm panel ta-c hidden" data-country="cm" language="fr">
# <div class="age-box">
# <svg class="logo">
# <use xlink:href="/media/img/logo-besoccer.svg#logo_fondo_blanco"></use>
# </svg>
# <p class="question mr5 mb20">Êtes-vous majeur ?</p>
# <div class="answers t-up">
# <a href="javascript:;" id="over18">OUI</a>
# <a href="javascript:;" id="less18">NON</a>
# </div>
# <p class="msg color-grey2 mt20">Confirmez que vous avez 18 ans</p>
# <img alt="Paris" class="img-footer" src="/media/img/faldon_bets_ley.png?v=2"/>
# </div>
# </div> </div>
# <script type="application/ld+json">
#     {
#         "@context": "https://schema.org",
#         "@type": "Organization",
#         "name": "Besoccer",
#         "url": "https://fr.besoccer.com",
#         "logo": "/media/img/imagotipo_besoccer.png"
#     }
# </script>
# <script type="application/ld+json">
#     {
#         "@context": "https://schema.org",
#         "@type": "WebSite",
#         "name": "BeSoccer | Résultats de foot",
#         "url": "https://fr.besoccer.com/"
#     }
# </script>
# <header class="header-search">
# <div class="search-box" style="--team-bg: #51a331">
# <div class="search">
# <div class="mobile-menu">
# <a class="burger" data-cy="burger" href="javascript:;" id="burger"><span></span></a>
# <div class="mobile-menu-list">
# <div class="hidden" data-loginstatus="logged">
# <div class="user-wrapper mh10">
# <a class="user-row" href="https://fr.besoccer.com/profil">
# <img alt="Usuario" class="head-user m0 pb0 userAvatar" src="https://cdn.resfu.com/avatar_166/5282886/5282886_gallery.jpg?size=100x&amp;lossy=1"/>
# <div>
# <div class="ml20" id="userName">User</div>
# <div class="user-email ml20 mt5" id="userEmail"></div>
# </div>
# </a>
# </div>
# </div>
# <div data-loginstatus="notLogged">
# <div class="user-wrapper mh10">
# <a class="user-row" href="https://fr.besoccer.com/se-connecter">
# <img alt="Usuario" class="head-user m0 pb0" src="/media/img/nofoto_user.png"/>
# <span class="ml20">Se connecter ou s'inscrire</span>
# </a>
# </div>
# </div>
# <ul>
# <li>
# <a href="https://fr.besoccer.com/resultats/2025-04-02">
# <svg class="menu-svg va-m" viewbox="0 0 90 90">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-home"></use>
# </svg>
# <span class="va-m">Matchs</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/infos">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-news"></use>
# </svg>
# <span class="va-m">Articles</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/explorer">
# <svg class="menu-svg va-m" viewbox="0 0 90 90">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-explore"></use>
# </svg>
# <span class="va-m">Explorer</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/competitions">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-competitions"></use>
# </svg>
# <span class="va-m">Compétitions</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/equipes">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-teams"></use>
# </svg>
# <span class="va-m">Équipes</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/joueurs">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-players"></use>
# </svg>
# <span class="va-m">Joueurs</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/transferts">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-transfer"></use>
# </svg>
# <span class="va-m">Transferts</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/rechercher-match">
# <svg class="menu-svg va-m" viewbox="0 0 90 90">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#match-searcher"></use>
# </svg>
# <span class="va-m">Chercher Match</span>
# </a>
# </li>
# <li>
# <a data-cy="televised" href="https://fr.besoccer.com/resultats/2025-04-02/tv">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-tv"></use>
# </svg>
# <span class="va-m">Diffusion</span>
# </a>
# </li>
# <li>
# <a href="https://fr.besoccer.com/favoris">
# <svg class="menu-svg va-m" viewbox="0 0 94 94">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#star"></use>
# </svg>
# <span class="va-m">Signets</span>
# </a>
# </li>
# <li class="mv5">
# <a class="popup_btn" href="#popup_settings">
# <img alt="Ajustes" class="menu-svg va-m w-30" src="/media/img/icons/ic_gear_w.svg?v=2" style="width: 30px;"/>
# <span class="va-m">Ajustes</span>
# </a>
# </li>
# <li class="mv5">
# <a class="popup_btn" href="#popup_langs">
# <img alt="Ajustes" class="menu-svg va-m w-30" src="/media/img/icons/ic_language_w.svg" style="width: 30px;"/>
# <span class="va-m">Langues</span>
# </a>
# </li>
# </ul>
# <div class="download-logo-box">
# <a href="https://play.google.com/store/apps/details?id=com.resultadosfutbol.mobile&amp;hl=fr" target="_blank">
# <img alt="Google Play" class="download-logo" loading="lazy" src="/media/img/badgets_store/dwn_android_fr.png"/>
# </a>
# <a href="https://apps.apple.com/cl/app/resultados-de-fútbol-besoccer/id550928207?l=fr" target="_blank">
# <img alt="App Store" class="download-logo" loading="lazy" src="/media/img/badgets_store/dwn_ios_fr.png"/>
# </a>
# </div>
# </div>
# </div>
# <div class="logo">
# <div class="row align-center">
# <h3>
# <a href="https://fr.besoccer.com/resultats/2025-04-02">
# <svg class="logo-svg big">
# <use xlink:href="/media/img/logo-besoccer.svg#logo_fondo_blanco"></use>
# </svg>
# <svg class="logo-svg small">
# <use xlink:href="/media/img/logo-besoccer-small.svg#logo_small"></use>
# </svg>
# </a>
# <span class="hidden">BeSoccer</span>
# </h3>
# <nav class="menu sel-menu view-more">
# <a class="active" href="https://fr.besoccer.com/resultats/2025-04-02">Matchs</a>
# <script type="application/ld+json">
#                                     {
#                                         "@context": "https://schema.org",
#                                         "@type": "SiteNavigationElement",
#                                         "name": "Matchs",
#                                         "url": "https://fr.besoccer.com/resultats/2025-04-02"
#                                     }
#                                 </script>
# <a class="" href="https://fr.besoccer.com/infos">Articles</a>
# <script type="application/ld+json">
#                                     {
#                                         "@context": "https://schema.org",
#                                         "@type": "SiteNavigationElement",
#                                         "name": "Articles",
#                                         "url": "https://fr.besoccer.com/infos"
#                                     }
#                                 </script>
# <a class="" href="https://fr.besoccer.com/explorer">Explorer</a>
# <script type="application/ld+json">
#                                     {
#                                         "@context": "https://schema.org",
#                                         "@type": "SiteNavigationElement",
#                                         "name": "Explorer",
#                                         "url": "https://fr.besoccer.com/explorer"
#                                     }
#                                 </script>
# <a class="" href="https://fr.besoccer.com/competitions">Compétitions</a>
# <script type="application/ld+json">
#                                     {
#                                         "@context": "https://schema.org",
#                                         "@type": "SiteNavigationElement",
#                                         "name": "Compétitions",
#                                         "url": "https://fr.besoccer.com/competitions"
#                                     }
#                                 </script>
# <a class="" href="https://fr.besoccer.com/equipes">Équipes</a>
# <script type="application/ld+json">
#                                     {
#                                         "@context": "https://schema.org",
#                                         "@type": "SiteNavigationElement",
#                                         "name": "Équipes",
#                                         "url": "https://fr.besoccer.com/equipes"
#                                     }
#                                 </script>
# <a class="" href="https://fr.besoccer.com/joueurs">Joueurs</a>
# <script type="application/ld+json">
#                                     {
#                                         "@context": "https://schema.org",
#                                         "@type": "SiteNavigationElement",
#                                         "name": "Joueurs",
#                                         "url": "https://fr.besoccer.com/joueurs"
#                                     }
#                                 </script>
# <a class="" href="https://fr.besoccer.com/transferts">Transferts</a>
# <script type="application/ld+json">
#                                     {
#                                         "@context": "https://schema.org",
#                                         "@type": "SiteNavigationElement",
#                                         "name": "Transferts",
#                                         "url": "https://fr.besoccer.com/transferts"
#                                     }
#                                 </script>
# <div class="menu-box ml5 mr10 list-box">
# <span class="dots-more"></span>
# <a href="javascript:;">Plus</a>
# <div class="box hidden mb0">
# <ul class="mm-menu more">
# <li><a class="" href="https://fr.besoccer.com/rechercher-match">Chercher Match</a>
# <script type="application/ld+json">
#                                                     {
#                                                         "@context": "https://schema.org",
#                                                         "@type": "SiteNavigationElement",
#                                                         "name": "Chercher Match",
#                                                         "url": "https://fr.besoccer.com/rechercher-match"
#                                                     }
#                                                 </script>
# </li>
# <li><a class="" href="https://fr.besoccer.com/resultats/2025-04-02/tv">Diffusion</a>
# <script type="application/ld+json">
#                                                     {
#                                                         "@context": "https://schema.org",
#                                                         "@type": "SiteNavigationElement",
#                                                         "name": "Diffusion",
#                                                         "url": "https://fr.besoccer.com/resultats/2025-04-02/tv"
#                                                     }
#                                                 </script>
# </li>
# <li><a class="" href="https://fr.besoccer.com/favoris">Signets</a>
# <script type="application/ld+json">
#                                                     {
#                                                         "@context": "https://schema.org",
#                                                         "@type": "SiteNavigationElement",
#                                                         "name": "Signets",
#                                                         "url": "https://fr.besoccer.com/favoris"
#                                                     }
#                                                 </script>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# <div class="back-btn" id="back_btn">
# <svg viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=3#arrow3"></use>
# </svg>
# </div>
# <div class="search-bar" id="search_bar">
# <input style="display:none" type="text"/><input style="display:none" type="password"/>
# <div class="search-svg hidden" id="search_svg">
# <svg class="search-magni" viewbox="10 12 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=3#magni"></use>
# </svg>
# </div>
# <input autocomplete="new-password" class="search-input" data-url="https://fr.besoccer.com/recherche" id="search_input" lang="fr" name="input_search_besoccer" placeholder="Rechercher..." type="text"/>
# <a class="search-mic" href="javascript:;" onclick="startDictation();">
# <div class="icon">
# <svg viewbox="10 10 40 40">
# <use xlink:href="/media/img/ico_svg_new.svg?v=3#micro"></use>
# </svg>
# </div>
# </a>
# <div class="search-btn" id="search_btn">
# <svg class="search-magni" viewbox="10 12 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=3#magni"></use>
# </svg>
# </div>
# <a class="close-btn hidden" href="javascript:;" id="close_btn">
# <svg class="search-close">
# <use xlink:href="/media/img/ico_svg.svg?v=8#close-btn"></use>
# </svg>
# </a>
# <div class="autocomplete-box">
# <ul id="autocomplete_values">
# </ul>
# <ul class="pl5" id="emptySearch">
# <li>
# <ul id="searchQuest"></ul>
# </li>
# <li class="elem-title pl10 pv10 t-up bold">Matchs les plus consultés</li>
# <li tabindex="1">
# <div class="match-list-new">
# <a class="match-link flex-1 fl-wrap jc-ce" href="https://fr.besoccer.com/match/atletico-madrid/barcelona/2025266068">
# <div class="team-info ta-r" itemscope="" itemtype="https://schema.org/SportsTeam">
# <div class="team-name ta-r">Atlético</div>
# <img alt="Atlético" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/369.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="1 time">21:30</p>
# </div>
# <div class="team-info">
# <img alt="Barcelona" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/429.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l">Barcelona</div>
# </div>
# <div class="date ta-c">02 Apr. 2025</div>
# </a>
# <div class="delete-favourites hidden">
# <svg class="trash-icon mr10" onclick="deleteFavorite( this, 7202349356 );">
# <use href="/media/img/app_icons/other/head_trash.svg?v=1#trash"></use>
# </svg>
# </div>
# </div>
# </li>
# <li tabindex="1">
# <div class="match-list-new">
# <a class="match-link flex-1 fl-wrap jc-ce" href="https://fr.besoccer.com/match/shanghai-shenhua/yunnan-yukun/2025257540">
# <div class="team-info ta-r" itemscope="" itemtype="https://schema.org/SportsTeam">
# <div class="team-name ta-r">Shanghai Shenhua</div>
# <img alt="Shanghai Shenhua" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/2320.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="1 time">12:00</p>
# </div>
# <div class="team-info">
# <img alt="Yunnan Yukun" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/157063.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l">Yunnan Yukun</div>
# </div>
# <div class="date ta-c">02 Apr. 2025</div>
# </a>
# <div class="delete-favourites hidden">
# <svg class="trash-icon mr10" onclick="deleteFavorite( this, 7202349356 );">
# <use href="/media/img/app_icons/other/head_trash.svg?v=1#trash"></use>
# </svg>
# </div>
# </div>
# </li>
# <li tabindex="1">
# <div class="match-list-new">
# <a class="match-link flex-1 fl-wrap jc-ce" href="https://fr.besoccer.com/match/liverpool/everton-fc/20256182">
# <div class="team-info ta-r" itemscope="" itemtype="https://schema.org/SportsTeam">
# <div class="team-name ta-r">Liverpool</div>
# <img alt="Liverpool" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/3845.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="1 time">21:00</p>
# </div>
# <div class="team-info">
# <img alt="Everton" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/1017.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l">Everton</div>
# </div>
# <div class="date ta-c">02 Apr. 2025</div>
# </a>
# <div class="delete-favourites hidden">
# <svg class="trash-icon mr10" onclick="deleteFavorite( this, 7202349356 );">
# <use href="/media/img/app_icons/other/head_trash.svg?v=1#trash"></use>
# </svg>
# </div>
# </div>
# </li>
# <li tabindex="1">
# <div class="match-list-new">
# <a class="match-link flex-1 fl-wrap jc-ce" href="https://fr.besoccer.com/match/brighton-amp-hov/aston-villa-fc/20256175">
# <div class="team-info ta-r" itemscope="" itemtype="https://schema.org/SportsTeam">
# <div class="team-name ta-r">Brighton &amp; Hove Albion</div>
# <img alt="Brighton &amp; Hove Albion" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/5652.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="1 time">20:45</p>
# </div>
# <div class="team-info">
# <img alt="Aston Villa" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/297.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l">Aston Villa</div>
# </div>
# <div class="date ta-c">02 Apr. 2025</div>
# </a>
# <div class="delete-favourites hidden">
# <svg class="trash-icon mr10" onclick="deleteFavorite( this, 7202349356 );">
# <use href="/media/img/app_icons/other/head_trash.svg?v=1#trash"></use>
# </svg>
# </div>
# </div>
# </li>
# <li tabindex="1">
# <div class="match-list-new">
# <a class="match-link flex-1 fl-wrap jc-ce" href="https://fr.besoccer.com/match/milan/internazionale/2025273591">
# <div class="team-info ta-r" itemscope="" itemtype="https://schema.org/SportsTeam">
# <div class="team-name ta-r">Milan</div>
# <img alt="Milan" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/1692.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="1 time">21:00</p>
# </div>
# <div class="team-info">
# <img alt="Inter" class="pv3 va-m team-shield" src="https://cdn.resfu.com/img_data/equipos/1381.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l">Inter</div>
# </div>
# <div class="date ta-c">02 Apr. 2025</div>
# </a>
# <div class="delete-favourites hidden">
# <svg class="trash-icon mr10" onclick="deleteFavorite( this, 7202349356 );">
# <use href="/media/img/app_icons/other/head_trash.svg?v=1#trash"></use>
# </svg>
# </div>
# </div>
# </li>
# <li class="elem-title pl10 pv10 mt10 t-up bold">Compétitions les plus recherchées</li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/competition/copa_del_rey">
# <img alt="Coupe du Roi" class="elem-img mr15" height="30" src="https://cdn.resfu.com/media/img/league_logos/copa-del-rey.png?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3">Coupe du Roi</p>
# <p class="sub-text color-grey2">Demi-finales</p>
# </div>
# <img alt="ic_search_competition_g" class="no-circle" src="https://cdn.resfu.com/img_data/ico_api/ic_search_competition_g.png"/>
# </a>
# </li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/competition/premier">
# <img alt="Premier League" class="elem-img mr15" height="30" src="https://cdn.resfu.com/media/img/league_logos/premier.png?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3">Premier League</p>
# <p class="sub-text color-grey2">Jor. 30</p>
# </div>
# <img alt="ic_search_competition_g" class="no-circle" src="https://cdn.resfu.com/img_data/ico_api/ic_search_competition_g.png"/>
# </a>
# </li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/competition/la_liga">
# <img alt="LaLiga" class="elem-img mr15" height="30" src="https://cdn.resfu.com/media/img/league_logos/primera-division-ea.png?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3">LaLiga</p>
# <p class="sub-text color-grey2">Jor. 30</p>
# </div>
# <img alt="ic_search_competition_g" class="no-circle" src="https://cdn.resfu.com/img_data/ico_api/ic_search_competition_g.png"/>
# </a>
# </li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/competition/champions">
# <img alt="Ligue des Champions" class="elem-img mr15" height="30" src="https://cdn.resfu.com/media/img/league_logos/champions.png?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3">Ligue des Champions</p>
# <p class="sub-text color-grey2">1/4 de finale</p>
# </div>
# <img alt="ic_search_competition_g" class="no-circle" src="https://cdn.resfu.com/img_data/ico_api/ic_search_competition_g.png"/>
# </a>
# </li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/competition/dfb_pokal">
# <img alt="DFB Pokal" class="elem-img mr15" height="30" src="https://cdn.resfu.com/media/img/league_logos/dfb_pokal.png?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3">DFB Pokal</p>
# <p class="sub-text color-grey2">Demi-finales</p>
# </div>
# <img alt="ic_search_competition_g" class="no-circle" src="https://cdn.resfu.com/img_data/ico_api/ic_search_competition_g.png"/>
# </a>
# </li>
# <li class="elem-title pl10 pv10 mt10 t-up bold">Joueurs les plus recherchés</li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/joueur/l-nasraoui-3189487">
# <img alt="Lamine Yamal" class="mr15" height="30" src="https://cdn.resfu.com/img_data/players/medium/3189487.jpg?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3"><b>Lamine Yamal</b></p>
# <p class="sub-text color-grey2 row align-center">
# <img alt="country" class="flag m0 va-m" src="https://cdn.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&amp;lossy=1"/>
# <span class="player-role bg-role att mh3">ATT</span>
# <span class="va-m">AD</span>
# </p>
# </div>
# <img alt="ic_search_player_g" class="no-circle" src="https://cdn.resfu.com/img_data/ico_api/ic_search_player_g.png"/>
# </a>
# </li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/joueur/d-alaba-58931">
# <img alt="David Alaba" class="mr15" height="30" src="https://cdn.resfu.com/img_data/players/medium/58931.jpg?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3"><b>David Alaba</b></p>
# <p class="sub-text color-grey2 row align-center">
# <img alt="country" class="flag m0 va-m" src="https://cdn.resfu.com/media/img/flags/st3/large/at.png?size=100x65c&amp;lossy=1"/>
# <span class="player-role bg-role def mh3">DEF</span>
# <span class="va-m">DG</span>
# </p>
# </div>
# <img alt="ic_search_player_g" class="no-circle" src="https://cdn.resfu.com/img_data/ico_api/ic_search_player_g.png"/>
# </a>
# </li>
# <li tabindex="1">
# <a class="pl5" href="https://fr.besoccer.com/joueur/endrick-987453">
# <img alt="Endrick" class="mr15" height="30" src="https://cdn.resfu.com/img_data/players/medium/987453.jpg?size=120x&amp;lossy=1"/>
# <div class="text-box">
# <p class="main-text mb3"><b>Endrick</b></p>
# <p class="sub-text color-grey2 row align-center">
# ...
# <div class="team-name ta-l" itemprop="name">Los Angeles FC II</div>
# </img></div>
# <div class="date ta-c">
# <span class="tag-nobg end"><b>Fin</b></span>
# </div>
# </div>
# </a>
# <a class="match-link match-home" data-cy="match" data-modindex="43" data-status="-1" hastime="0" href="https://fr.besoccer.com/match/portland-hearts-of-pine/hartford-athletic/2025286468" id="match-2025286468" locale="fr" starttime="2025-04-03T00:30:00+02:00">
# <div class="info-head">
# <div class="right-info">
# <div class="tvs">
# </div>
# </div>
# <div class="right-info no-of ta-r">
# </div>
# </div>
# <div class="team-box">
# <div class="team-info ta-r" itemtype="http://schema.org/SportsTeam">
# <div class="team-name ta-r" itemprop="name">Portland Hearts of Pine</div>
# <img alt="Portland Hearts of Pine" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/166080.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="match_hour time">23:30</p>
# </div>
# <div class="team-info" itemtype="http://schema.org/SportsTeam">
# <img alt="Hartford Athletic" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/119273.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l" itemprop="name">Hartford Athletic</div>
# </div>
# <div class="date ta-c">
# <span class="tag-nobg"><b></b></span>
# </div>
# </div>
# </a>
# <a class="match-link match-home" data-cy="match" data-modindex="44" data-status="-1" hastime="0" href="https://fr.besoccer.com/match/loudoun-united/virginia-drean/2025286469" id="match-2025286469" locale="fr" starttime="2025-04-03T00:30:00+02:00">
# <div class="info-head">
# <div class="right-info">
# <div class="tvs">
# </div>
# </div>
# <div class="right-info no-of ta-r">
# </div>
# </div>
# <div class="team-box">
# <div class="team-info ta-r" itemtype="http://schema.org/SportsTeam">
# <div class="team-name ta-r" itemprop="name">Loudoun United</div>
# <img alt="Loudoun United" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/119274.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="match_hour time">23:30</p>
# </div>
# <div class="team-info" itemtype="http://schema.org/SportsTeam">
# <img alt="Virginia Dream" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/156887.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l" itemprop="name">Virginia Dream</div>
# </div>
# <div class="date ta-c">
# <span class="tag-nobg"><b></b></span>
# </div>
# </div>
# </a>
# </div>
# </div> </div>
# <div class="" id="mod_panel">
# <div class="panel hiddenPanel" style="display:none;">
# <div class="panel-head">
# <a data-cy="competitionName" href="https://fr.besoccer.com/competition/uefa_youth_league">
# <div class="t-up">
# <div class="panel-title">
# <img alt="Uefa Youth League" class="comp-img va-m" loading="lazy" src="https://cdn.resfu.com/media/img/flags/st3/small/ue.png?size=30x&amp;lossy=1"/>
# <span class="va-m">Uefa Youth League</span>
# </div>
# </div>
# </a>
# <div class="view-more" data-cy="divDot">
# <a class="dots view_more_btn" data-cy="openDotMenu" href="javascript:;">
# <div class="dot"></div>
# </a>
# <div class="mm-menu">
# <ul>
# <li class="favouritesPopupBtn">
# <a class="popup_btn" href="#popup_alerts_0" onclick='popupAlertFav(`Uefa Youth League`, `529`, `[{"id":"278309","l":"VfB Stuttgart U19","v":"Barcelona U19","y":"2025","k":"529_0","al":"vfb-stuttgart-sub19","av":"fc-barcelona-juvenil","lid":"60932","vid":"4871","s":"-1","trend":"","ld":"15:00","full_date":"02\/04\/2025","utc":"2025-04-02 14:00:00"},{"id":"278306","l":"AZ Alkmaar U19","v":"Man. City U19","y":"2025","k":"529_0","al":"az-alkmaar-sub19","av":"man-city-sub-19","lid":"61620","vid":"16060","s":"-1","trend":"","ld":"17:00","full_date":"02\/04\/2025","utc":"2025-04-02 16:00:00"}]`)'>
#                                 Définir les favoris                            </a>
# </li>
# <li>
# <a data-cy="competitionDetail" href="https://fr.besoccer.com/competition/uefa_youth_league" rel="nofollow">
#                                 Aller à la compétition                            </a>
# </li>
# <li>
# <a data-cy="competitionNews" href="https://fr.besoccer.com/infos/competition/uefa_youth_league" rel="nofollow">
#                                     Aller aux informations                                </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="panel-body p0 match-list-new panel view-more">
# <a class="match-link match-home" data-cy="match" data-modindex="45" data-status="-1" hastime="0" href="https://fr.besoccer.com/match/vfb-stuttgart-sub19/fc-barcelona-juvenil/2025278309" id="match-2025278309" locale="fr" starttime="2025-04-02T16:00:00+02:00">
# <div class="info-head">
# <div class="right-info">
# <div class="tvs">
# </div>
# </div>
# <div class="right-info no-of ta-r">
# </div>
# </div>
# <div class="team-box">
# <div class="team-info ta-r" itemtype="http://schema.org/SportsTeam">
# <div class="team-name ta-r" itemprop="name">VfB Stuttgart U19</div>
# <img alt="VfB Stuttgart U19" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/60932.png?size=60x&amp;lossy=1">
# </img></div>
# <div class="marker">
# <p class="match_hour time">15:00</p>
# </div>
# <div class="team-info" itemtype="http://schema.org/SportsTeam">
# <img alt="Barcelona U19" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/4871.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l" itemprop="name">Barcelona U19</div>
# </div>
# <div class="date ta-c">
# <span class="tag-nobg"><b></b></span>
# </div>
# </div>
# </a>
# <a class="match-link match-home" data-cy="match" data-modindex="46" data-status="-1" hastime="0" href="https://fr.besoccer.com/match/az-alkmaar-sub19/man-city-sub-19/2025278306" id="match-2025278306" locale="fr" starttime="2025-04-02T18:00:00+02:00">
# <div class="info-head">
# <div class="right-info">
# <div class="tvs">
# </div>
# </div>
# <div class="right-info no-of ta-r">
# </div>
# </div>
# <div class="team-box">
# <div class="team-info ta-r" itemtype="http://schema.org/SportsTeam">
# <div class="team-name ta-r" itemprop="name">AZ Alkmaar U19</div>
# <img alt="AZ Alkmaar U19" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/61620.png?size=60x&amp;lossy=1"/>
# </div>
# <div class="marker">
# <p class="match_hour time">17:00</p>
# </div>
# <div class="team-info" itemtype="http://schema.org/SportsTeam">
# <img alt="Man. City U19" class="pv3 va-m team-shield" itemprop="image" loading="lazy" src="https://cdn.resfu.com/img_data/equipos/16060.png?size=60x&amp;lossy=1"/>
# <div class="team-name ta-l" itemprop="name">Man. City U19</div>
# </div>
# <div class="date ta-c">
# <span class="tag-nobg"><b></b></span>
# </div>
# </div>
# </a>
# </div>
# </div> </div>
# </div>
# </div>
# <input id="livescore_url" type="hidden" value="https://fr.besoccer.com/resultats">
# <script>
#     document.addEventListener('DOMContentLoaded', () => {
#         generateMatches( "bf3ec7104826f8ac0bb140a7054269c9", "null", '{"req":"home_matches","vr":9,"isocode":"cm","locale":24,"extra":60,"date":"2025-04-02","lang":"fr"}');
#     })
# </script> </input></div>
# <div class="grid-item" id="mod_mobile_bottom_menu">
# <div class="fixed-menu bottom">
# <a class="ta-c ib active" href="https://fr.besoccer.com/resultats/2025-04-02">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-matches"></use>
# </svg>
# <div class="va-m">Matchs</div>
# </a>
# <a class="ta-c ib" href="https://fr.besoccer.com/explorer">
# <svg class="menu-svg va-m" viewbox="0 0 90 90">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-explore"></use>
# </svg>
# <div class="va-m">Explorer</div>
# </a>
# <a class="ta-c ib" href="https://fr.besoccer.com/transferts">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-transfer"></use>
# </svg>
# <div class="va-m">Transferts</div>
# </a>
# <a class="ta-c ib" href="https://fr.besoccer.com/infos">
# <svg class="menu-svg va-m" viewbox="0 0 50 50">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#menu-news"></use>
# </svg>
# <div class="va-m">Articles</div>
# </a>
# <a class="ta-c ib" href="https://fr.besoccer.com/favoris">
# <svg class="menu-svg va-m" viewbox="0 0 94 94">
# <use xlink:href="/media/img/ico_svg_new.svg?v=5#star"></use>
# </svg>
# <div class="va-m">Signets</div>
# </a>
# </div> </div>
# </div>
# </section>
# </main> <footer class="footer">
# <div class="footer-left">
# <div class="copyright">Copyright © 2014-2025 BeSoccer.com, Live Scores | <a href="https://fr.besoccer.com/legal" rel="nofollow">Mentions légales et confidentialité</a><br/>Jouez responsable. 18+</div>
# </div>
# <div data-status1="Fin" data-status2="Rep." data-status3="Extra" data-status4="Pen" data-status5="MT" id="matches_attr"></div>
# <div class="footer-right">
# <div class="utilities-box">
# <div class="sm-border">
# <div class="social-media">
# <a href="https://www.facebook.com/rfutbol" rel="nofollow" target="_blank">
# <svg class="sm-img" viewbox="0 0 40 40">
# <use xlink:href="/media/img/ico_svg_new.svg#facebook"></use>
# </svg>
# </a>
# <a href="https://twitter.com/besoccerFR" rel="nofollow" target="_blank">
# <svg class="sm-img" viewbox="0 0 24 24">
# <use xlink:href="/media/img/ico_svg_new.svg#twitter"></use>
# </svg>
# </a>
# <a href="https://www.youtube.com/channel/UCGAvm_Zz0-hZ6nWmxeHLhlQ" rel="nofollow" target="_blank">
# <svg class="sm-img" viewbox="0 4 40 40">
# <use xlink:href="/media/img/ico_svg_new.svg#youtube"></use>
# </svg>
# </a>
# <a href="https://www.instagram.com/besoccer.fr" rel="nofollow" target="_blank">
# <svg class="sm-img" viewbox="14 15 76 76">
# <use xlink:href="/media/img/ico_svg_new.svg#instagram"></use>
# </svg>
# </a>
# </div>
# </div>
# <div class="utilities-box">
# <div class="downloads">
# <a href="https://apps.apple.com/cl/app/resultados-de-fútbol-besoccer/id550928207?l=fr" target="_blank"><img alt="AppStore" class="download" loading="lazy" src="/media/img/badgets_store/dwn_ios_fr.png"/></a>
# <a href="https://play.google.com/store/apps/details?id=com.resultadosfutbol.mobile&amp;hl=es" target="_blank"><img alt="GooglePlay" class="download" loading="lazy" src="/media/img/badgets_store/dwn_android_fr.png"/></a>
# <a href="https://appgallery.cloud.huawei.com/ag/n/app/C100094381?channelId=BeSoccer&amp;id=f1211652806445259cf5bd332b012fb6&amp;s=44DB2CA19F77FC080F4A7F833E79FC46D1868D23D297152A3B081152FAD57BFA&amp;detailType=0&amp;v=" target="_blank"><img alt="Huawei AppGallery" class="download" loading="lazy" src="/media/img/badgets_store/dwn_huawei_fr.png"/></a>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-box" id="version-box" style="z-index: 9999; display:none;">
# <p class="mb5 color-white hidden" id="version-box-msg-es">Puedes ver la versión Española de BeSoccer.com.</p>
# <p class="mb5 color-white hidden" id="version-box-msg-en">You can see the English version of BeSoccer.com.</p>
# <p class="mb5 color-white hidden" id="version-box-msg-fr">Vous pouvez voir la version French de BeSoccer.com.</p>
# <p class="mb5 color-white hidden" id="version-box-msg-it">Puoi vedere la versione Italian su BeSoccer.com.</p>
# <p class="mb5 color-white hidden" id="version-box-msg-pt">Você pode ver a versão Brasileira de BeSoccer.com.</p>
# <div class="btn ta-c">
# <a class="text mr5 hidden" href="javascript:;" id="version-box-link-es">Versión Española</a>
# <a class="text mr5 hidden" href="javascript:;" id="version-box-link-en">Version English</a>
# <a class="text mr5 hidden" href="javascript:;" id="version-box-link-fr">Version French</a>
# <a class="text mr5 hidden" href="javascript:;" id="version-box-link-it">Versione Italian</a>
# <a class="text mr5 hidden" href="javascript:;" id="version-box-link-pt">Versão Brasileira</a>
# <a class="close-msg" href="javascript:;" id="version-msg-box-ignore">X</a>
# </div>
# </div>
# </footer>
# <script>
#             if ( !subscriptionCookie ) {
#
#                 loadScript('/media/js/newLogic.js?rand=20250402.52636');
#
#             }
#         </script>
# <link href="/media/css/ads.css?rand=20250402.52610" rel="stylesheet"/>
# <script src="/media/js/magnific-popup.js?rand=20250402.526"></script>
# <script src="/media/js/dayjs/dayjs.min.js"></script>
# <script src="/media/js/dayjs/locale/fr.js"></script>
# <script src="/media/js/js.cookie.min.js?rand=20250402.526"></script>
# <script src="/media/js/noCookies.js?rand=20250402.5261"></script>
# <div class="hidden" id="choice-footer-msg"></div>
# <script>
#             (function() { // Asigna un padding al content para que no esté debajo de la cabecera
#                 if (document.getElementsByClassName('header-search').length) {
#                     var headerHeight = document.getElementsByClassName('header-search')[0].offsetHeight;
#                     var content = document.getElementsByClassName('content')[0];
#                     content.style.paddingTop = headerHeight+'px';
#                 }
#             })();
#         </script>
# <script type="text/javascript">
#             var msnry = null;
#
#             function reloadMasonry() {
#                 if (msnry !== null) {
#                     msnry = new Masonry('.grid-container', {
#                         itemSelector: ".grid-item",
#                         columnWidth: ".grid-sizer",
#                         percentPosition: true
#                     });
#                 }
#             }
#
#
#             // Check Masonry container exists
#             if (document.querySelector('.grid-container')) {
#                 checkWidth = function() {
#                     var windowWidth = window.innerWidth;
#                     if (windowWidth >= 767) {
#                         // Load Script Dinamically
#                         var masonryScript = document.createElement("script");
#                         masonryScript.setAttribute("type", "text/javascript");
#                         masonryScript.setAttribute("src", "/media/js/masonry.js?v=20250402.526");
#                         document.body.appendChild(masonryScript);
#
#                         masonryScript.onload = function() {
#                             // Init Masonry
#                             msnry = new Masonry('.grid-container', {
#                                 itemSelector: ".grid-item",
#                                 columnWidth: ".grid-sizer",
#                                 percentPosition: true
#                             });
#                         }
#                     }
#                 };
#
#                 $(document).ready(function() {
#                     checkWidth();
#                 });
#
#                 // Refresh with heart beats logic
#                 (function masonry_poll(ms = 2000) {
#                     var timeout = ms;
#                     setTimeout(function () {
#                         reloadMasonry();
#                         masonry_poll(timeout);
#                     }, timeout);
#                 })();
#
#
#                 document.addEventListener('DOMContentLoaded', () => {
#                     reloadMasonry();
#                 });
#
#                 $(window).on("resize", function(){
#                     reloadMasonry();
#                 });
#             }
#         </script>
# <script src="/media/js/config.js?rand=20250402.526"></script>
# <script src="/media/js/common.js?rand=20250402.5263"></script>
# <script async="" src="/media/js/autocomplete.js?v=20250402.526"></script>
# <script src="/media/js/horizontalscroll.js?rand=20250402.5265"></script>
# <script src="/media/js/jquery-ui-1.12.4.min.js?rand=20250402.5265"></script>
# <script src="/media/js/datepicker/datapicker.js?rand=20250402.5265"></script>
# <script src="/media/js/datepicker/datepicker-fr.js?rand=20250402.5265"></script>
# <script src="/media/js/userLogin.js?rand=20250402.5265"></script>
# <script src="/media/js/userRegister.js?rand=20250402.5265"></script>
# <script src="/media/js/infinityScroll.js?rand=20250402.5265"></script>
# <script src="/media/js/favourites/favourites.js?rand=20250402.5265"></script>
# <script src="/media/js/liveButton.js?rand=20250402.5265"></script>
# </body>
# </html>

# %%
TOKEN = "44ce18b703cb4a84b791cd7ed042d293"

headers = {"X-Auth-Token": TOKEN}

match = requests.get(url="https://api.football-data.org/v4/matches/", headers=headers)

print(match.json())
# Out:
# {'filters': {'dateFrom': '2025-04-02', 'dateTo': '2025-04-03', 'permission': 'TIER_ONE'}, 'resultSet': {'count': 15, 'competitions': 'CLI,DED,ELC,PL,PPL', 'first': '2025-04-02', 'last': '2025-04-02', 'played': 0}, 'matches': [{'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 2366, 'startDate': '2025-02-05', 'endDate': '2025-11-29', 'currentMatchday': 2, 'winner': None}, 'id': 535915, 'utcDate': '2025-04-02T00:30:00Z', 'status': 'IN_PLAY', 'matchday': 1, 'stage': 'GROUP_STAGE', 'group': 'GROUP_E', 'lastUpdated': '2025-04-02T02:59:57Z', 'homeTeam': {'id': 4430, 'name': 'CA Bucaramanga', 'shortName': 'CA Bucaramanga', 'tla': 'CAB', 'crest': 'https://crests.football-data.org/4430.png'}, 'awayTeam': {'id': 4410, 'name': 'CSD Colo-Colo', 'shortName': 'Colo-Colo', 'tla': 'COL', 'crest': 'https://crests.football-data.org/4410.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 0}, 'halfTime': {'home': None, 'away': None}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 2366, 'startDate': '2025-02-05', 'endDate': '2025-11-29', 'currentMatchday': 2, 'winner': None}, 'id': 535916, 'utcDate': '2025-04-02T00:30:00Z', 'status': 'IN_PLAY', 'matchday': 1, 'stage': 'GROUP_STAGE', 'group': 'GROUP_E', 'lastUpdated': '2025-04-02T02:59:57Z', 'homeTeam': {'id': 3984, 'name': 'Fortaleza EC', 'shortName': 'Fortaleza', 'tla': 'FEC', 'crest': 'https://crests.football-data.org/3984.png'}, 'awayTeam': {'id': 6803, 'name': 'Racing Club', 'shortName': 'Racing Club', 'tla': 'RAC', 'crest': 'https://crests.football-data.org/6803.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 1}, 'halfTime': {'home': None, 'away': None}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 2366, 'startDate': '2025-02-05', 'endDate': '2025-11-29', 'currentMatchday': 2, 'winner': None}, 'id': 535879, 'utcDate': '2025-04-02T02:00:00Z', 'status': 'TIMED', 'matchday': 1, 'stage': 'GROUP_STAGE', 'group': 'GROUP_B', 'lastUpdated': '2025-04-02T02:47:57Z', 'homeTeam': {'id': 4520, 'name': 'Barcelona SC', 'shortName': 'Barcelona SC', 'tla': 'BAR', 'crest': 'https://crests.football-data.org/4520.png'}, 'awayTeam': {'id': 6989, 'name': 'CAR Independiente del Valle', 'shortName': 'Independiente', 'tla': 'IDL', 'crest': 'https://crests.football-data.org/6989.png'}, 'score': {'winner': None, 'duration': 'REGULAR', 'fullTime': {'home': None, 'away': None}, 'halfTime': {'home': None, 'away': None}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': []}, {'area': {'id': 2220, 'name': 'South America', 'code': 'SAM', 'flag': 'https://crests.football-data.org/CLI.svg'}, 'competition': {'id': 2152, 'name': 'Copa Libertadores', 'code': 'CLI', 'type': 'CUP', 'emblem': 'https://crests.football-data.org/CLI.svg'}, 'season': {'id': 2366, 'startDate': '2025-02-05', 'endDate': '2025-11-29', 'currentMatchday': 2, 'winner': None}, 'id': 535903, 'utcDate': '2025-04-02T02:00:00Z', 'status': 'TIMED', 'matchday': 1, 'stage': 'GROUP_STAGE', 'group': 'GROUP_D', 'lastUpdated': '2025-04-02T02:50:04Z', 'homeTeam': {'id': 5680, 'name': 'Club Alianza Lim ...
